# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import seaborn as sns

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
descriptive_stats = data.describe()



print(descriptive_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 descriptive_stats = data.describe()
#       5 print(descriptive_stats)
#
# NameError: name 'data' is not defined

# %%
missing_values =data.isnull().sum()


print(missing_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 missing_values =data.isnull().sum()
#       4 print(missing_values)
#
# NameError: name 'data' is not defined

# %%
data1= pd.read_csv("StudentsPerformance.csv")
data1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1.shape
# Out:
# (1000, 8)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
descriptive_stats = data1.describe()



print(descriptive_stats)
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
missing_values =data1.isnull().sum()


print(missing_values)
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
numerical_columns = data1.select_dtypes(include='number').columns
data1[numerical_columns] = data1[numerical_columns].fillna(data1[numerical_columns].mean())


categorical_columns = data1.select_dtypes(include='object').columns
data1[categorical_columns] = data1[categorical_columns].fillna(data1[categorical_columns].mode().iloc[0])

# %%
missing_values =data1.isnull().sum()


print(missing_values)
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data1['math score'], bins=30, kde = True)
plt.xlabel('math score')
plt.ylabel('Count')
plt.title('Histogram of Math Score')
plt.show()

# %%
sns.countplot(x = "gender", data = data1)
plt.xlabel('gender')
plt.ylabel('Count')
plt.title('Count of Gender')
plt.show()

# %%
data1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.countplot(x = "gender", data = data1)
plt.xlabel('gender')
plt.ylabel('Count')
plt.title('Count of Gender')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.countplot(x = "parental level of education", data = data1)
plt.xlabel('Level of Education')
plt.ylabel('Count')
plt.title('Count of Education')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data1['writing score'])
plt.xlabel('writing score')
plt.title('Box Plot of Writing Score')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data1.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\769838444.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data1.corr(), annot=True, cmap='coolwarm', fmt='.2f')

# %%
sns.countplot(x = "race/ethnicity", data = data1)
plt.xlabel('Race/Ethnicity')
plt.ylabel('Count')
plt.title('Count of Race/Ethnicity')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.pairplot(data1, vars=['math score', 'writing score'], hue='gender')
plt.suptitle('Pairplot of Math Score & Writing Score (colored by gender)')
plt.show()

# %%
sns.violinplot(x = "race/ethnicity", y='reading score', data = data1)
plt.xlabel('Reading Score')
plt.ylabel('Race/Ethnicity')
plt.title('Distribution of Reading Score across Race/Ethnicity')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.boxplot(x = "parental level of education", y='math score', data = data1)
plt.xlabel('Level of education')
plt.ylabel('Math Score')
plt.title('Comparison of Math Score for different Level Of Education')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.scatterplot(x = "reading score", y='writing score', data = data1, hue='gender')
plt.xlabel('reading score')
plt.ylabel('writing score')
plt.title('Scatter Plot of Reading vs.Writing Score(colored by gender)')
plt.show()

# %%
sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
#Plotting a Distplot
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\2266090491.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show() #Plotting a Distplot Without the Histogram
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\3132386034.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()       #Visualization of Normal Distribution!
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\2114496968.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
#Visualization of Binomial Distribution
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\1610902048.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %%
#Difference Between Normal and Binomial Distribution
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\1307664369.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\1307664369.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#Visualization of Poisson Distribution
sns.distplot(random.poisson(lam=2, size=1000), kde=False)

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\2884709739.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)

# %%
#Difference Between Normal and Poisson Distribution
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\3069968504.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\3069968504.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#Difference Between Binomial and Poisson Distribution
sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial')
sns.distplot(random.poisson(lam=10, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\3225185403.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial')
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\3225185403.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
import seaborn as sns
sns.set_theme()
df = sns.load_dataset("penguins")         #distplot vs histplot vs displot

# %%
sns.distplot(df["flipper_length_mm"])
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\3043958594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["flipper_length_mm"])
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.histplot(df["flipper_length_mm"])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot(df["flipper_length_mm"])

# %%
sns.histplot(df, x="flipper_length_mm", alpha=.4)
sns.rugplot(df, x="flipper_length_mm")            #Adding a rug
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot(df, x="flipper_length_mm", alpha=.4, rug=True)

# %%
#Replicating basic distplot output
sns.histplot(df["flipper_length_mm"], kde=True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(df["flipper_length_mm"], kde=True, stat="density")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.histplot(
    df["flipper_length_mm"], kde=True,
    stat="density", kde_kws=dict(cut=3)
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
#Showing a density curve
sns.distplot(df["flipper_length_mm"], hist=False)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\4287837699.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["flipper_length_mm"], hist=False)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.displot(df["flipper_length_mm"], kind="kde")

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)                                              #A high-level API for statistical graphics

# %%
#Statistical estimation
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %%
import seaborn as sns

import matplotlib.pyplot as plt




iris = sns.load_dataset("iris")




# customize the histogram

sns.histplot(data=iris, x="petal_length", bins=20, kde=True, color="green")




# add labels and title

plt.xlabel("Petal Length (cm)")

plt.ylabel("Frequency")

plt.title("Distribution of Petal Lengths in Iris Flowers")




# display the plot

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load the "tips" dataset from Seaborn

tips = sns.load_dataset("tips")




# Create a density plot of the "total_bill" column from the "tips" dataset

# We use the "hue" parameter to differentiate between "lunch" and "dinner" meal times

# We use the "fill" parameter to fill the area under the curve

# We adjust the "alpha" and "linewidth" parameters to make the plot more visually appealing

sns.kdeplot(data=tips, x="total_bill", hue="time", fill=True, alpha=0.6, linewidth=1.5)




# Add a title and labels to the plot using Matplotlib

plt.title("Density Plot of Total Bill by Meal Time")

plt.xlabel("Total Bill ($)")

plt.ylabel("Density")




# Show the plot

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# load the tips dataset from Seaborn

tips = sns.load_dataset("tips")




# create a box plot of total bill by day and meal time, using the "hue" parameter to differentiate between lunch and dinner

# customize the color scheme using the "palette" parameter

# adjust the linewidth and fliersize parameters to make the plot more visually appealing

sns.boxplot(x="day", y="total_bill", hue="time", data=tips, palette="Set3", linewidth=1.5, fliersize=4)




# add a title, xlabel, and ylabel to the plot using Matplotlib functions

plt.title("Box Plot of Total Bill by Day and Meal Time")

plt.xlabel("Day of the Week")

plt.ylabel("Total Bill ($)")




# display the plot

plt.show()

# %%
import seaborn as sns




# load the iris dataset from Seaborn

iris = sns.load_dataset("iris")




# create a violin plot of petal length by species

sns.violinplot(x="species", y="petal_length", data=iris)




# display the plot

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load the dataset

tips = sns.load_dataset('tips')




# Create a heatmap of the correlation between variables

corr = tips.corr()

sns.heatmap(corr)




# Show the plot

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\2412632666.py:17: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = tips.corr()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load the dataset

flights = sns.load_dataset('flights')




# Pivot the data

flights = flights.pivot('month', 'year', 'passengers')




# Create a heatmap

sns.heatmap(flights, cmap='Blues', annot=True, fmt='d')




# Set the title and axis labels

plt.title('Passengers per month')

plt.xlabel('Year')

plt.ylabel('Month')




# Show the plot

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12596\2592014459.py:17: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot('month', 'year', 'passengers')

# %%
import seaborn as sns




# Load iris dataset

iris = sns.load_dataset("iris")




# Create pair plot

sns.pairplot(data=iris)




# Show plot

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load iris dataset

iris = sns.load_dataset("iris")




# Create pair plot with custom settings

sns.pairplot(data=iris, hue="species", diag_kind="kde", palette="husl")




# Set title

plt.title("Iris Dataset Pair Plot")




# Show plot

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# load iris dataset

iris = sns.load_dataset("iris")




# plot a joint plot of sepal length and sepal width

sns.jointplot(x="sepal_length", y="sepal_width", data=iris)




# display the plot

plt.show()
